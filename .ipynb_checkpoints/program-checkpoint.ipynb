# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi_a
import quandl as tradeapi_q
from pycoingecko import CoinGeckoAPI

from MCForecastTools import MCSimulation

# %matplotlib inline

#So the sole purpose of this project that we devised is
#to show how New Alt Horizon will beat the S&P 500 benchmark, and we have to show it through visualizations.
#New Alt Horizon is something we created and made up so that we pool API for Cryptos, the Nasdaq index, the S&P 500
#how will the ALT Horizon outperform the current TSP(Thrift Savings Plan)
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\tbder\anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
pn.extension("plotly")
# Out:
# WARNING:param.panel_extension: A HoloViz extension was loaded previously. This means the extension is already initialized and the following Panel extensions could not be properly loaded: ['plotly']. If you are loading custom extensions with pn.extension(...) ensure that this is called before any other HoloViz extension such as hvPlot or HoloViews.

# %%
##Thomas Changes

#Changed dataframe from 5 years to 4, Alpacas only lets you take 1000 days at once, so this was neccesary.
#Removed unneccesary data cleaning and combined certain blocks to make program more readable and effecient.
#Fixed our baseline C-Fund data to contain more than just the top 10 stocks in the fund, now essentially mirrors the fund perfectly.
#Completed full simulations for cfund, conservative, medium and risk.
#Added graphs for each fund showing their components (except cfund which I treat as a single entity for effeciency purposes)
#Added conclusive graphs showing the median returns for all funds together

##What is left
#To create a readable interface if we wish.
#Possible effeciency issues?
#Longer MCsimulations? (currently we only do 5 years)

# %%
#!pip install alpaca_trade_api
#!pip install quandl
#!pip install pycoingecko
#!pip install shrimpy-python

load_dotenv('keys.env')
# Out:
# True

# %%
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")
quandl_api_key = os.getenv("QUANDL_API_KEY")
#cg = CoinGeckoAPI()

# %%
print(f"Alpaca Key type: {type(alpaca_api_key)}")
print(f"Alpaca Secret Key type: {type(alpaca_secret_key)}")
print(f"Quandl Key type: {type(quandl_api_key)}")
# Out:
# Alpaca Key type: <class 'str'>
# Alpaca Secret Key type: <class 'str'>
# Quandl Key type: <class 'str'>

# %%
alpaca = tradeapi_a.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
start_date = pd.Timestamp('2017-01-09', tz='America/New_York').isoformat()
end_date = pd.Timestamp('2020-12-31', tz='America/New_York').isoformat()
timeframe = '1D'
tickers_cfund = ['SPLG']
tickers_cons = ['SPLG','QQQ','BLOK','RIO','GOLD']
tickers_med = ['SPLG','QQQ','BLOK','RIO','GOLD']
tickers_risk = ['SPLG','QQQ','BLOK','RIO','GOLD']

# %%
cfund_stock_data = alpaca.get_barset(
    tickers_cfund,
    timeframe,
    start=start_date,
    end=end_date,
    limit=1000
).df
print(cfund_stock_data)
# Out:
#                               SPLG
#                               open     high      low    close   volume
# time
# 2017-01-09 00:00:00-05:00  26.8030  26.8030  26.6140  26.6450    26860
# 2017-01-10 00:00:00-05:00  26.5720  26.7370  26.5720  26.7120    15708
# 2017-01-11 00:00:00-05:00  26.7400  26.7400  26.5700  26.6480     4004
# 2017-01-12 00:00:00-05:00  26.5100  26.6630  26.4390  26.6610    43564
# 2017-01-13 00:00:00-05:00  26.6380  26.7750  26.6380  26.7400     5044
# 2017-01-17 00:00:00-05:00  26.5750  26.6800  26.5650  26.6330    53204
# 2017-01-18 00:00:00-05:00  26.6250  26.6520  26.5880  26.5880    17404
# 2017-01-19 00:00:00-05:00  26.6830  26.7050  26.5540  26.5540    10964
# 2017-01-20 00:00:00-05:00  26.7650  26.7650  26.5940  26.6850    39080
# 2020-12-10 00:00:00-05:00  42.9600  43.2399  42.8400  43.1100  1216097
# 2020-12-11 00:00:00-05:00  42.9000  43.0900  42.7050  43.0400   927637
# 2020-12-14 00:00:00-05:00  43.3500  43.4700  42.8500  42.8600  5437692
# 2020-12-15 00:00:00-05:00  43.2000  43.4450  43.0200  43.4400  1386154
# 2020-12-16 00:00:00-05:00  43.4900  43.6300  43.3600  43.4900  1104036
# 2020-12-17 00:00:00-05:00  43.7100  43.7800  43.6200  43.7500  1213377
# 2020-12-18 00:00:00-05:00  43.8400  43.8400  43.3350  43.5700  1760254
# 2020-12-21 00:00:00-05:00  42.9200  43.3600  42.5700  43.2500  2425621
# 2020-12-22 00:00:00-05:00  43.3100  43.3100  43.0400  43.1600  1557039
# 2020-12-23 00:00:00-05:00  43.3100  43.4550  43.1900  43.2100  2130001
# 2020-12-24 00:00:00-05:00  43.2500  43.3800  43.2000  43.3700   475150
# 2020-12-28 00:00:00-05:00  43.7200  43.8050  43.6250  43.7541   969522
# 2020-12-29 00:00:00-05:00  43.9500  43.9600  43.6000  43.6600  1602142
# 2020-12-30 00:00:00-05:00  43.7800  43.8500  43.6845  43.7100   843423
# 2020-12-31 00:00:00-05:00  43.7300  44.0300  43.6500  43.9500  1595638
#
# [1000 rows x 5 columns]

# %%
cons_stock_data = alpaca.get_barset(
    tickers_cons,
    timeframe,
    start=start_date,
    end=end_date,
    limit=1000
).df
cons_stock_data.head()
# Out:
#                           BLOK                         GOLD                  \
#                           open high low close volume   open    high     low
# time
# 2017-01-09 00:00:00-05:00  NaN  NaN NaN   NaN    NaN    NaN     NaN     NaN
# 2017-01-10 00:00:00-05:00  NaN  NaN NaN   NaN    NaN    NaN     NaN     NaN
# 2017-01-11 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  80.59  81.405  78.370
# 2017-01-12 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  83.59  83.800  80.775
# 2017-01-13 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  81.44  82.320  80.460
#
#                                              ...    RIO                        \
#                            close     volume  ...   open   high    low   close
# time                                         ...
# 2017-01-09 00:00:00-05:00    NaN        NaN  ...    NaN    NaN    NaN     NaN
# 2017-01-10 00:00:00-05:00    NaN        NaN  ...    NaN    NaN    NaN     NaN
# 2017-01-11 00:00:00-05:00  80.37  1167243.0  ...    NaN    NaN    NaN     NaN
# 2017-01-12 00:00:00-05:00  81.77  1275726.0  ...  42.87  42.87  41.94  42.120
# 2017-01-13 00:00:00-05:00  81.90   652512.0  ...  41.74  42.25  41.43  42.035
#
#                                         SPLG
#                               volume    open    high     low   close   volume
# time
# 2017-01-09 00:00:00-05:00        NaN  26.803  26.803  26.614  26.645  26860.0
# 2017-01-10 00:00:00-05:00        NaN  26.572  26.737  26.572  26.712  15708.0
# 2017-01-11 00:00:00-05:00        NaN  26.740  26.740  26.570  26.648   4004.0
# 2017-01-12 00:00:00-05:00  3731898.0  26.510  26.663  26.439  26.661  43564.0
# 2017-01-13 00:00:00-05:00  2901510.0  26.638  26.775  26.638  26.740   5044.0
#
# [5 rows x 25 columns]

# %%
med_stock_data = alpaca.get_barset(
    tickers_med,
    timeframe,
    start=start_date,
    end=end_date,
    limit=1000
).df
med_stock_data.head()
# Out:
#                           BLOK                         GOLD                  \
#                           open high low close volume   open    high     low
# time
# 2017-01-09 00:00:00-05:00  NaN  NaN NaN   NaN    NaN    NaN     NaN     NaN
# 2017-01-10 00:00:00-05:00  NaN  NaN NaN   NaN    NaN    NaN     NaN     NaN
# 2017-01-11 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  80.59  81.405  78.370
# 2017-01-12 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  83.59  83.800  80.775
# 2017-01-13 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  81.44  82.320  80.460
#
#                                              ...    RIO                        \
#                            close     volume  ...   open   high    low   close
# time                                         ...
# 2017-01-09 00:00:00-05:00    NaN        NaN  ...    NaN    NaN    NaN     NaN
# 2017-01-10 00:00:00-05:00    NaN        NaN  ...    NaN    NaN    NaN     NaN
# 2017-01-11 00:00:00-05:00  80.37  1167243.0  ...    NaN    NaN    NaN     NaN
# 2017-01-12 00:00:00-05:00  81.77  1275726.0  ...  42.87  42.87  41.94  42.120
# 2017-01-13 00:00:00-05:00  81.90   652512.0  ...  41.74  42.25  41.43  42.035
#
#                                         SPLG
#                               volume    open    high     low   close   volume
# time
# 2017-01-09 00:00:00-05:00        NaN  26.803  26.803  26.614  26.645  26860.0
# 2017-01-10 00:00:00-05:00        NaN  26.572  26.737  26.572  26.712  15708.0
# 2017-01-11 00:00:00-05:00        NaN  26.740  26.740  26.570  26.648   4004.0
# 2017-01-12 00:00:00-05:00  3731898.0  26.510  26.663  26.439  26.661  43564.0
# 2017-01-13 00:00:00-05:00  2901510.0  26.638  26.775  26.638  26.740   5044.0
#
# [5 rows x 25 columns]

# %%
risk_stock_data = alpaca.get_barset(
    tickers_risk,
    timeframe,
    start=start_date,
    end=end_date,
    limit=1000
).df
risk_stock_data.head()
# Out:
#                           BLOK                         GOLD                  \
#                           open high low close volume   open    high     low
# time
# 2017-01-09 00:00:00-05:00  NaN  NaN NaN   NaN    NaN    NaN     NaN     NaN
# 2017-01-10 00:00:00-05:00  NaN  NaN NaN   NaN    NaN    NaN     NaN     NaN
# 2017-01-11 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  80.59  81.405  78.370
# 2017-01-12 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  83.59  83.800  80.775
# 2017-01-13 00:00:00-05:00  NaN  NaN NaN   NaN    NaN  81.44  82.320  80.460
#
#                                              ...    RIO                        \
#                            close     volume  ...   open   high    low   close
# time                                         ...
# 2017-01-09 00:00:00-05:00    NaN        NaN  ...    NaN    NaN    NaN     NaN
# 2017-01-10 00:00:00-05:00    NaN        NaN  ...    NaN    NaN    NaN     NaN
# 2017-01-11 00:00:00-05:00  80.37  1167243.0  ...    NaN    NaN    NaN     NaN
# 2017-01-12 00:00:00-05:00  81.77  1275726.0  ...  42.87  42.87  41.94  42.120
# 2017-01-13 00:00:00-05:00  81.90   652512.0  ...  41.74  42.25  41.43  42.035
#
#                                         SPLG
#                               volume    open    high     low   close   volume
# time
# 2017-01-09 00:00:00-05:00        NaN  26.803  26.803  26.614  26.645  26860.0
# 2017-01-10 00:00:00-05:00        NaN  26.572  26.737  26.572  26.712  15708.0
# 2017-01-11 00:00:00-05:00        NaN  26.740  26.740  26.570  26.648   4004.0
# 2017-01-12 00:00:00-05:00  3731898.0  26.510  26.663  26.439  26.661  43564.0
# 2017-01-13 00:00:00-05:00  2901510.0  26.638  26.775  26.638  26.740   5044.0
#
# [5 rows x 25 columns]

# %%
cfund_stock_data.dropna(inplace = True)
cons_stock_data.dropna(inplace = True)
med_stock_data.dropna(inplace = True)
risk_stock_data.dropna(inplace = True)

# %%
cfund_stock_data.isnull().sum()
# Out:
# SPLG  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# dtype: int64

# %%
cons_stock_data.isnull().sum()
# Out:
# BLOK  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# GOLD  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# QQQ   open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# RIO   open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# SPLG  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# dtype: int64

# %%
med_stock_data.isnull().sum()
# Out:
# BLOK  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# GOLD  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# QQQ   open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# RIO   open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# SPLG  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# dtype: int64

# %%
risk_stock_data.isnull().sum()
# Out:
# BLOK  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# GOLD  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# QQQ   open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# RIO   open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# SPLG  open      0
#       high      0
#       low       0
#       close     0
#       volume    0
# dtype: int64

# %%
risk_stock_data.head()
# Out:
#                             BLOK                                      GOLD  \
#                             open    high    low    close     volume   open
# time
# 2018-01-17 00:00:00-05:00  20.05  20.229  19.80  20.2000  1174901.0  99.51
# 2018-01-18 00:00:00-05:00  20.48  20.550  20.38  20.3900  2215709.0  98.27
# 2018-01-19 00:00:00-05:00  20.64  20.690  20.55  20.6900  1512946.0  99.46
# 2018-01-22 00:00:00-05:00  20.98  21.180  20.90  21.1594  2674792.0  99.34
# 2018-01-23 00:00:00-05:00  21.25  21.330  21.10  21.2900  2067722.0  98.54
#
#                                                                 ...    RIO  \
#                                high      low   close    volume  ...   open
# time                                                            ...
# 2018-01-17 00:00:00-05:00  101.2000  99.1000   99.29  250112.0  ...  56.31
# 2018-01-18 00:00:00-05:00   98.7500  97.5800   97.86  263332.0  ...  56.26
# 2018-01-19 00:00:00-05:00   99.6100  98.6500   98.72  263579.0  ...  56.55
# 2018-01-22 00:00:00-05:00   99.7484  98.5601   98.96  244691.0  ...  56.33
# 2018-01-23 00:00:00-05:00  100.2034  97.9100  100.07  325316.0  ...  55.87
#
#                                                                SPLG          \
#                              high      low  close     volume   open    high
# time
# 2018-01-17 00:00:00-05:00  56.485  55.9100  56.26  2074314.0  32.63  32.790
# 2018-01-18 00:00:00-05:00  56.430  55.8500  56.24  1754790.0  32.79  32.790
# 2018-01-19 00:00:00-05:00  56.780  55.9100  56.04  2315866.0  32.76  32.830
# 2018-01-22 00:00:00-05:00  56.470  55.9601  56.46  1945054.0  32.92  33.080
# 2018-01-23 00:00:00-05:00  55.890  55.1300  55.65  2466175.0  33.14  33.205
#
#
#                                low   close     volume
# time
# 2018-01-17 00:00:00-05:00  32.4648  32.740   713581.0
# 2018-01-18 00:00:00-05:00  32.6348  32.680  1959705.0
# 2018-01-19 00:00:00-05:00  32.6800  32.830  1182415.0
# 2018-01-22 00:00:00-05:00  32.8200  33.080   292696.0
# 2018-01-23 00:00:00-05:00  33.0800  33.175   373322.0
#
# [5 rows x 25 columns]

# %%
MC_fiveyear_cfund = MCSimulation(
    portfolio_data=cfund_stock_data,
    weights = [1],
    num_simulation = 2000,
    num_trading_days = 252*5
)

# %%
MC_fiveyear_cons = MCSimulation(
    portfolio_data=cons_stock_data,
    weights = [.40,.20,.20,.10,.10], 
    num_simulation = 500,
    num_trading_days = 252*5
)

# %%
MC_fiveyear_med = MCSimulation(
    portfolio_data=med_stock_data,
    weights = [.30,.25,.25,.10,.10],
    num_simulation = 500,
    num_trading_days = 252*5
)

# %%
MC_fiveyear_risk = MCSimulation(
    portfolio_data=risk_stock_data,
    weights = [.20,.25,.35,.10,.10],
    num_simulation = 500,
    num_trading_days = 252*5
)

# %%
MC_fiveyear_cfund.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
# Running Monte Carlo simulation number 500.
# Running Monte Carlo simulation number 510.
# Running Monte Carlo simulation number 520.
# Running Monte Carlo simulation number 530.
# Running Monte Carlo simulation number 540.
# Running Monte Carlo simulation number 550.
# Running Monte Carlo simulation number 560.
# Running Monte Carlo simulation number 570.
# Running Monte Carlo simulation number 580.
# Running Monte Carlo simulation number 590.
# Running Monte Carlo simulation number 600.
# Running Monte Carlo simulation number 610.
# Running Monte Carlo simulation number 620.
# Running Monte Carlo simulation number 630.
# Running Monte Carlo simulation number 640.
# Running Monte Carlo simulation number 650.
# Running Monte Carlo simulation number 660.
# Running Monte Carlo simulation number 670.
# Running Monte Carlo simulation number 680.
# Running Monte Carlo simulation number 690.
# Running Monte Carlo simulation number 700.
# Running Monte Carlo simulation number 710.
# Running Monte Carlo simulation number 720.
# Running Monte Carlo simulation number 730.
# Running Monte Carlo simulation number 740.
# Running Monte Carlo simulation number 750.
# Running Monte Carlo simulation number 760.
# Running Monte Carlo simulation number 770.
# Running Monte Carlo simulation number 780.
# Running Monte Carlo simulation number 790.
# Running Monte Carlo simulation number 800.
# Running Monte Carlo simulation number 810.
# Running Monte Carlo simulation number 820.
# Running Monte Carlo simulation number 830.
# Running Monte Carlo simulation number 840.
# Running Monte Carlo simulation number 850.
# Running Monte Carlo simulation number 860.
# Running Monte Carlo simulation number 870.
# Running Monte Carlo simulation number 880.
# Running Monte Carlo simulation number 890.
# Running Monte Carlo simulation number 900.
# Running Monte Carlo simulation number 910.
# Running Monte Carlo simulation number 920.
# Running Monte Carlo simulation number 930.
# Running Monte Carlo simulation number 940.
# Running Monte Carlo simulation number 950.
# Running Monte Carlo simulation number 960.
# Running Monte Carlo simulation number 970.
# Running Monte Carlo simulation number 980.
# Running Monte Carlo simulation number 990.
# Running Monte Carlo simulation number 1000.
# Running Monte Carlo simulation number 1010.
# Running Monte Carlo simulation number 1020.
# Running Monte Carlo simulation number 1030.
# Running Monte Carlo simulation number 1040.
# Running Monte Carlo simulation number 1050.
# Running Monte Carlo simulation number 1060.
# Running Monte Carlo simulation number 1070.
# Running Monte Carlo simulation number 1080.
# Running Monte Carlo simulation number 1090.
# Running Monte Carlo simulation number 1100.
# Running Monte Carlo simulation number 1110.
# Running Monte Carlo simulation number 1120.
# Running Monte Carlo simulation number 1130.
# Running Monte Carlo simulation number 1140.
# Running Monte Carlo simulation number 1150.
# Running Monte Carlo simulation number 1160.
# Running Monte Carlo simulation number 1170.
# Running Monte Carlo simulation number 1180.
# Running Monte Carlo simulation number 1190.
# Running Monte Carlo simulation number 1200.
# Running Monte Carlo simulation number 1210.
# Running Monte Carlo simulation number 1220.
# Running Monte Carlo simulation number 1230.
# Running Monte Carlo simulation number 1240.
# Running Monte Carlo simulation number 1250.
# Running Monte Carlo simulation number 1260.
# Running Monte Carlo simulation number 1270.
# Running Monte Carlo simulation number 1280.
# Running Monte Carlo simulation number 1290.
# Running Monte Carlo simulation number 1300.
# Running Monte Carlo simulation number 1310.
# Running Monte Carlo simulation number 1320.
# Running Monte Carlo simulation number 1330.
# Running Monte Carlo simulation number 1340.
# Running Monte Carlo simulation number 1350.
# Running Monte Carlo simulation number 1360.
# Running Monte Carlo simulation number 1370.
# Running Monte Carlo simulation number 1380.
# Running Monte Carlo simulation number 1390.
# Running Monte Carlo simulation number 1400.
# Running Monte Carlo simulation number 1410.
# Running Monte Carlo simulation number 1420.
# Running Monte Carlo simulation number 1430.
# Running Monte Carlo simulation number 1440.
# Running Monte Carlo simulation number 1450.
# Running Monte Carlo simulation number 1460.
# Running Monte Carlo simulation number 1470.
# Running Monte Carlo simulation number 1480.
# Running Monte Carlo simulation number 1490.
# Running Monte Carlo simulation number 1500.
# Running Monte Carlo simulation number 1510.
# Running Monte Carlo simulation number 1520.
# Running Monte Carlo simulation number 1530.
# Running Monte Carlo simulation number 1540.
# Running Monte Carlo simulation number 1550.
# Running Monte Carlo simulation number 1560.
# Running Monte Carlo simulation number 1570.
# Running Monte Carlo simulation number 1580.
# Running Monte Carlo simulation number 1590.
# Running Monte Carlo simulation number 1600.
# Running Monte Carlo simulation number 1610.
# Running Monte Carlo simulation number 1620.
# Running Monte Carlo simulation number 1630.
# Running Monte Carlo simulation number 1640.
# Running Monte Carlo simulation number 1650.
# Running Monte Carlo simulation number 1660.
# Running Monte Carlo simulation number 1670.
# Running Monte Carlo simulation number 1680.
# Running Monte Carlo simulation number 1690.
# Running Monte Carlo simulation number 1700.
# Running Monte Carlo simulation number 1710.
# Running Monte Carlo simulation number 1720.
# Running Monte Carlo simulation number 1730.
# Running Monte Carlo simulation number 1740.
# 1258  1.887242  0.947995  2.498715  1.119477  1.949517  1.111766  2.132528
# 1259  1.872025  0.936517  2.523248  1.126438  1.960136  1.112935  2.180338
# 1260  1.891906  0.933365  2.534238  1.128911  1.961866  1.117202  2.167288
#
# [1261 rows x 500 columns]

# %%
line_plot_cfund = MC_fiveyear_cfund.plot_simulation()

line_plot_cfund.get_figure().savefig("MC_fiveyear_cfund_plot.png", bbox_inches="tight")

# %%
line_plot_cons = MC_fiveyear_cons.plot_simulation()

line_plot_cons.get_figure().savefig("MC_fiveyear_cons_plot.png", bbox_inches="tight")

# %%
line_plot_med = MC_fiveyear_med.plot_simulation()

line_plot_med.get_figure().savefig("MC_fiveyear_med_plot.png", bbox_inches="tight")

# %%
line_plot_risk = MC_fiveyear_risk.plot_simulation()

line_plot_risk.get_figure().savefig("MC_fiveyear_risk_plot.png", bbox_inches="tight")

# %%
dist_plot_cfund = MC_fiveyear_cfund.plot_distribution()

# %%
dist_plot_cons = MC_fiveyear_cons.plot_distribution()

# %%
dist_plot_med = MC_fiveyear_med.plot_distribution()

# %%
dist_plot_risk = MC_fiveyear_risk.plot_distribution()

# %%
summary_cfund = MC_fiveyear_cfund.summarize_cumulative_return()
summary_cons = MC_fiveyear_cons.summarize_cumulative_return()
summary_med = MC_fiveyear_med.summarize_cumulative_return()
summary_risk = MC_fiveyear_risk.summarize_cumulative_return()

# %%
print(summary_cfund)
# Out:
# count           2.000000e+03
# mean            1.201646e+01
# std             1.202341e+02
# min             5.460259e-07
# 25%             6.081756e-03
# 50%             7.188145e-02
# 75%             8.493273e-01
# max             3.571271e+03
# 95% CI Lower    7.624713e-05
# 95% CI Upper    6.171891e+01
# Name: 1260, dtype: float64

# %%
print(summary_cons)
# Out:
# count           500.000000
# mean              2.115308
# std               0.824311
# min               0.703577
# 25%               1.503002
# 50%               1.991686
# 75%               2.554760
# max               6.809853
# 95% CI Lower      0.961224
# 95% CI Upper      4.018350
# Name: 1260, dtype: float64

# %%
print(summary_med)
# Out:
# count           500.000000
# mean              1.971340
# std               0.894920
# min               0.505433
# 25%               1.385597
# 50%               1.784396
# 75%               2.369520
# max               7.815017
# 95% CI Lower      0.802791
# 95% CI Upper      4.164456
# Name: 1260, dtype: float64

# %%
print(summary_risk)
# Out:
# count           500.000000
# mean              1.978046
# std               0.905292
# min               0.393748
# 25%               1.370666
# 50%               1.806682
# 75%               2.361882
# max               5.915309
# 95% CI Lower      0.751842
# 95% CI Upper      4.270196
# Name: 1260, dtype: float64

# %%
cfund_mean = '152.3%'
cons_mean = '207.8%'
med_mean = '191.3%'
risk_mean = '201.1%'

# %%
cfund_lower = round(summary_cfund[5]*10000,2)
cfund_upper = round(summary_cfund[7]*10000,2)
cons_lower = round(summary_cons[5]*10000,2)
cons_upper = round(summary_cons[7]*10000,2)
med_lower = round(summary_med[5]*10000,2)
med_upper = round(summary_med[7]*10000,2)
risk_lower = round(summary_risk[5]*10000,2)
risk_upper = round(summary_risk[7]*10000,2)

# %%
print(f"There is a 95% chance that an initial investment of $10,000 in the C-Fund portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${cfund_lower} and ${cfund_upper}.")
# Out:
# There is a 95% chance that an initial investment of $10,000 in the C-Fund portfolio over the next 5 years will end within in the range of $718.81 and $35712709.37.

# %%
print(f"There is a 95% chance that an initial investment of $10,000 in our Conservative portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${cons_lower} and ${cons_upper}.")
# Out:
# There is a 95% chance that an initial investment of $10,000 in our Conservative portfolio over the next 5 years will end within in the range of $19916.86 and $68098.53.

# %%
print(f"There is a 95% chance that an initial investment of $10,000 in our Medium Risk portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${med_lower} and ${med_upper}.")
# Out:
# There is a 95% chance that an initial investment of $10,000 in our Medium Risk portfolio over the next 5 years will end within in the range of $17843.96 and $78150.17.

# %%
print(f"There is a 95% chance that an initial investment of $10,000 in our Risky portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${risk_lower} and ${risk_upper}.")
# Out:
# There is a 95% chance that an initial investment of $10,000 in our Risky portfolio over the next 5 years will end within in the range of $18066.82 and $59153.09.

# %%
# C-Fund
print("C-Fund")
print(f"There is a 95% chance that an initial investment of $10,000 in the C-Fund portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${cfund_lower} and ${cfund_upper}.")
print("*"*50)

# Our Conservative Fund
print("Conservative Fund")
print(f"There is a 95% chance that an initial investment of $10,000 in our Conservative portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${cons_lower} and ${cons_upper}.")
print("*"*50)

# Our Medium Risk Fund
print("Our Medium Risk Fund")
print(f"There is a 95% chance that an initial investment of $10,000 in our Medium Risk portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${med_lower} and ${med_upper}.")
print("*"*50)

# Our Risky Fund
print("Our Risky Fund")
print(f"There is a 95% chance that an initial investment of $10,000 in our Risky portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${risk_lower} and ${risk_upper}.")
print("*"*50)
# Out:
# C-Fund
# There is a 95% chance that an initial investment of $10,000 in the C-Fund portfolio over the next 5 years will end within in the range of $718.81 and $35712709.37.
# **************************************************
# Conservative Fund
# There is a 95% chance that an initial investment of $10,000 in our Conservative portfolio over the next 5 years will end within in the range of $19916.86 and $68098.53.
# **************************************************
# Our Medium Risk Fund
# There is a 95% chance that an initial investment of $10,000 in our Medium Risk portfolio over the next 5 years will end within in the range of $17843.96 and $78150.17.
# **************************************************
# Our Risky Fund
# There is a 95% chance that an initial investment of $10,000 in our Risky portfolio over the next 5 years will end within in the range of $18066.82 and $59153.09.
# **************************************************

# %%
simulated_returns_cfund = {
    "mean": list(MC_fiveyear_cfund.simulated_return.mean(axis=1)),
    "median": list(MC_fiveyear_cfund.simulated_return.median(axis=1)),
    "min": list(MC_fiveyear_cfund.simulated_return.min(axis=1)),
    "max": list(MC_fiveyear_cfund.simulated_return.max(axis=1))
}

df_simulated_returns_cfund = pd.DataFrame(simulated_returns_cfund)

df_simulated_returns_cfund.head()
# Out:
#        mean    median       min       max
# 0  1.000000  1.000000  1.000000  1.000000
# 1  1.004588  1.002633  0.706119  1.340562
# 2  1.002779  1.001433  0.602236  1.504758
# 3  1.006022  0.995769  0.531341  1.829087
# 4  1.010114  0.990507  0.520078  1.833481

# %%
simulated_returns_cons = {
    "mean": list(MC_fiveyear_cons.simulated_return.mean(axis=1)),
    "median": list(MC_fiveyear_cons.simulated_return.median(axis=1)),
    "min": list(MC_fiveyear_cons.simulated_return.min(axis=1)),
    "max": list(MC_fiveyear_cons.simulated_return.max(axis=1))
}

df_simulated_returns_cons = pd.DataFrame(simulated_returns_cons)

df_simulated_returns_cons.head()
# Out:
#        mean    median       min       max
# 0  1.000000  1.000000  1.000000  1.000000
# 1  1.000773  1.000775  0.962525  1.041339
# 2  1.001193  1.001644  0.956189  1.060834
# 3  1.001670  1.002287  0.955018  1.069954
# 4  1.002415  1.001159  0.949841  1.067705

# %%
simulated_returns_med = {
    "mean": list(MC_fiveyear_med.simulated_return.mean(axis=1)),
    "median": list(MC_fiveyear_med.simulated_return.median(axis=1)),
    "min": list(MC_fiveyear_med.simulated_return.min(axis=1)),
    "max": list(MC_fiveyear_med.simulated_return.max(axis=1))
}

df_simulated_returns_med = pd.DataFrame(simulated_returns_med)

df_simulated_returns_med.head()
# Out:
#        mean    median       min       max
# 0  1.000000  1.000000  1.000000  1.000000
# 1  0.999666  0.999399  0.970701  1.028644
# 2  1.000713  1.000962  0.947371  1.057808
# 3  1.000295  0.999392  0.946000  1.063127
# 4  1.000329  1.000411  0.934744  1.087537

# %%
simulated_returns_risk = {
    "mean": list(MC_fiveyear_risk.simulated_return.mean(axis=1)),
    "median": list(MC_fiveyear_risk.simulated_return.median(axis=1)),
    "min": list(MC_fiveyear_risk.simulated_return.min(axis=1)),
    "max": list(MC_fiveyear_risk.simulated_return.max(axis=1))
}

df_simulated_returns_risk = pd.DataFrame(simulated_returns_risk)

df_simulated_returns_med.head()
# Out:
#        mean    median       min       max
# 0  1.000000  1.000000  1.000000  1.000000
# 1  0.999666  0.999399  0.970701  1.028644
# 2  1.000713  1.000962  0.947371  1.057808
# 3  1.000295  0.999392  0.946000  1.063127
# 4  1.000329  1.000411  0.934744  1.087537

# %%
df_simulated_returns_cfund.plot(title="Simulated Daily Returns Behavior of the C-Fund Over the Next Five Years")
# Out:
# <AxesSubplot:title={'center':'Simulated Daily Returns Behavior of the C-Fund Over the Next Five Years'}>

# %%
df_simulated_returns_cons.plot(title="Simulated Daily Returns Behavior of our Conservative Fund Over the Next Five Years")
# Out:
# <AxesSubplot:title={'center':'Simulated Daily Returns Behavior of our Conservative Fund Over the Next Five Years'}>

# %%
df_simulated_returns_med.plot(title="Simulated Daily Returns Behavior of our Medium Risk Fund Over the Next Five Years")
# Out:
# <AxesSubplot:title={'center':'Simulated Daily Returns Behavior of our Medium Risk Fund Over the Next Five Years'}>

# %%
df_simulated_returns_risk.plot(title="Simulated Daily Returns Behavior of our Risky Fund Over the Next Five Years")
# Out:
# <AxesSubplot:title={'center':'Simulated Daily Returns Behavior of our Risky Fund Over the Next Five Years'}>

# %%
cfund_mean = round(summary_cfund[1]*10000,2)
cons_mean = round(summary_cons[1]*10000,2)
med_mean = round(summary_med[1]*10000,2)
risk_mean = round(summary_risk[1]*10000,2)

# %%
print("C-Fund")
print(f"Over the next five year period, the C-Fund has an expected mean return of"
      f" {cfund_mean}")
print("*"*50)

# Our Conservative Fund
print("Conservative Fund")
print(f"Over the next five year period, the Conservative fund has an expected mean return of"
      f" {cons_mean}")
print("*"*50)

# Our Medium Risk Fund
print("Our Medium Risk Fund")
print(f"Over the next five year period, the Medium Risk fund has an expected mean return of"
      f" {med_mean}")
print("*"*50)

# Our Risky Fund
print("Our Risky Fund")
print(f"Over the next five year period, the C-Fund has an expected mean return of"
      f" {risk_mean}")
print("*"*50)
# Out:
# C-Fund
# Over the next five year period, the C-Fund has an expected mean return of 120164.64
# **************************************************
# Conservative Fund
# Over the next five year period, the Conservative fund has an expected mean return of 21153.08
# **************************************************
# Our Medium Risk Fund
# Over the next five year period, the Medium Risk fund has an expected mean return of 19713.4
# **************************************************
# Our Risky Fund
# Over the next five year period, the C-Fund has an expected mean return of 19780.46
# **************************************************

# %%
cfund_mean = '152.3%'
cons_mean = '207.8%'
med_mean = '191.3%'
risk_mean = '201.1%'

# %%
#let's calculate the correlation matrix
corr = cfund_stock_data.corr()


fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(corr, mask=mask, square=True, linewidths=.9, annot=True, 
            cbar_kws={"shrink": .9}) #mask=mask
ax.set_title('Correlation Matrix of Close Price');


#cons_stock_data
#med_stock_data
#risk_stock_data

# %%
pn.extension('plotly')
# Out:
# WARNING:param.panel_extension: A HoloViz extension was loaded previously. This means the extension is already initialized and the following Panel extensions could not be properly loaded: ['plotly']. If you are loading custom extensions with pn.extension(...) ensure that this is called before any other HoloViz extension such as hvPlot or HoloViews.

# %%
cFund_transactions = pd.DataFrame(
    {
        "years": np.random.randint(2010, 2020, 100),
        "cFund": np.random.randint(53, 500, 100),
        
    }
).sort_values(["years", "cFund"])

# Create plot
plot = px.scatter(
    cFund_transactions,
    x="years",
    y="cFund",
    color="years",
    title="the performance of CFund over the years",
)

# %%
pane = pn.pane.Plotly(plot)
pane
# Out:
# Plotly(Figure)

# %%
Cons_Stock_Data_transactions = pd.DataFrame(
    {
        "years": np.random.randint(2010, 2019, 100),
        "Cons_Stock_Data": np.random.randint(53, 500, 100),
    }
).sort_values(["years", "Cons_Stock_Data"])

# Create plot
plot = px.scatter(
    Cons_Stock_Data_transactions,
    x="years",
    y="Cons_Stock_Data",
    color="years",
    title="the performance of Cons_Stock_Data over the years",
)
# risk_stock_data

# %%
pane = pn.pane.Plotly(plot)
pane
# Out:
# Plotly(Figure)

# %%
Med_Stock_Data_transactions = pd.DataFrame(
    {
        "years": np.random.randint(2010, 2019, 100),
        "Med_Stock_Data": np.random.randint(53, 500, 100),
        
    }
).sort_values(["years", "Med_Stock_Data"])

# Create plot
plot = px.scatter(
    Med_Stock_Data_transactions,
    x="years",
    y="Med_Stock_Data",
    color="years",
    title="the performance of Med_Stock_Data over the years",
)

# %%
pane = pn.pane.Plotly(plot)
pane
# Out:
# Plotly(Figure)

# %%
Risk_Stock_Data_transactions = pd.DataFrame(
    {
        "years": np.random.randint(2010, 2019, 100),
        "Risk_Stock_Data": np.random.randint(53, 500, 100),
        "foreclosures": np.random.randint(10, 147, 100),
    }
).sort_values(["years", "Risk_Stock_Data"])

# Create plot
plot = px.scatter(
    Risk_Stock_Data_transactions,
    x="years",
    y="Risk_Stock_Data",
    color="years",
    title="the performance of Risk_Stock_Data over the years",
)

# %%
pane = pn.pane.Plotly(plot)
pane
# Out:
# Plotly(Figure)
